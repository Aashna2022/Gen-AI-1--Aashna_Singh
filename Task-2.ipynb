# %%
# create a list named products containing at least 6 product names
products = ["Laptop", "Fruit", "Headphones", "Pants", "Camera", "Smartwatch"]

# parallel list containing the category for each product
categories = ["Electronics", "Edible", "Electronics", "Wearables", "Photography", "Wearables"]

# create a set of unique categories
category_set = set(categories)

print(category_set)
# Out:
# {'Edible', 'Electronics', 'Wearables', 'Photography'}

# %%
category_set.add('Accessories')
print(category_set)
# Out:
# {'Accessories', 'Electronics', 'Wearables', 'Photography', 'Edible'}

# %%
category_set.add('Electronics')
print(category_set)
# Out:
# {'Accessories', 'Electronics', 'Wearables', 'Photography', 'Edible'}

# %%
# check wether a category exists in the set
if 'Electronics' in category_set:
    print("Electronics category exists in the set.")
else:
    print("Electronics category does not exist in the set.")
# Out:
# Electronics category exists in the set.

# %%
print("Electronics" in category_set)   # True
print("Accessories" in category_set)   # True
# Out:
# True
# True

# %%
print("Total no. of unique categories:", len(category_set))
# Out:
# Total no. of unique categories: 5
